# %% [markdown]
# <a href="https://colab.research.google.com/github/cmlangford13/Water-Security/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-44125ae2-33f8-4858-b8ab-91130e5d0f83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44125ae2-33f8-4858-b8ab-91130e5d0f83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('water_insecurity_2023.csv',encoding = "latin-1")
df.head(20)
# Out:
#     geoid                                  name  year  \
# 0    1003               Baldwin County, Alabama  2023
# 1    1069               Houston County, Alabama  2023
# 2    6037        Los Angeles County, California  2023
# 3    6087         Santa Cruz County, California  2023
# 4    6097             Sonoma County, California  2023
# 5    6013       Contra Costa County, California  2023
# 6   10001                 Kent County, Delaware  2023
# 7   12017                Citrus County, Florida  2023
# 8   12071                   Lee County, Florida  2023
# 9   12101                 Pasco County, Florida  2023
# 10  12033              Escambia County, Florida  2023
# 11   2090  Fairbanks North Star Borough, Alaska  2023
# 12  13185               Lowndes County, Georgia  2023
# 13  13127                 Glynn County, Georgia  2023
# 14  13051               Chatham County, Georgia  2023
# 15  13179               Liberty County, Georgia  2023
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 854 entries, 0 to 853
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   geoid                     854 non-null    int64
#  1   name                      854 non-null    object
#  2   year                      854 non-null    int64
#  3   geometry                  854 non-null    object
#  4   total_pop                 854 non-null    int64
#  5   plumbing                  853 non-null    float64
#  6   percent_lacking_plumbing  853 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 46.8+ KB

# %%
df.describe()
# Out:
#               geoid    year     total_pop     plumbing  \
# count    854.000000   854.0  8.540000e+02   853.000000
# mean   30586.902810  2023.0  3.374373e+05   253.726846
# std    16169.750921     0.0  5.777309e+05   438.988262
# min     1003.000000  2023.0  6.366100e+04     0.000000
# 25%    17125.000000  2023.0  9.674200e+04    41.000000
# 50%    34004.000000  2023.0  1.630865e+05   129.000000
# 75%    42105.500000  2023.0  3.483168e+05   299.000000
# max    72139.000000  2023.0  9.663345e+06  5248.000000
#
#        percent_lacking_plumbing
# count                853.000000
# mean                   0.101927
# std                    0.206700
# min                    0.000000
# 25%                    0.022079
# 50%                    0.060439
# 75%                    0.117170
# max                    3.913217

# %%
df.isnull().sum()
# Out:
# geoid                       0
# name                        0
# year                        0
# geometry                    0
# total_pop                   0
# plumbing                    1
# percent_lacking_plumbing    1
# dtype: int64

# %%
df['plumbing']
# Out:
# 0       271.0
# 1        30.0
# 2      5248.0
# 3       187.0
# 4       308.0
#         ...
# 849      30.0
# 850     121.0
# 851     125.0
# 852     145.0
# 853     682.0
# Name: plumbing, Length: 854, dtype: float64

# %%
df.dtypes
# Out:
# geoid                         int64
# name                         object
# year                          int64
# geometry                     object
# total_pop                     int64
# plumbing                    float64
# percent_lacking_plumbing    float64
# dtype: object

# %%
df.size
df.shape
# Out:
# (854, 7)
